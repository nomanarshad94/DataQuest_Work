# %%
import pandas as pd
import sqlite3
conn= sqlite3.connect("factbook.db")
q = "SELECT * FROM sqlite_master WHERE type='table';"
pd.read_sql_query(q, conn)
# Out:
#     type             name         tbl_name  rootpage  \
# 0  table  sqlite_sequence  sqlite_sequence         3
# 1  table            facts            facts        47
#
#                                                  sql
# 0             CREATE TABLE sqlite_sequence(name,seq)
# 1  CREATE TABLE "facts" ("id" INTEGER PRIMARY KEY...

# %% [markdown]
# * name - The name of the country.
# * area - The total land and sea area of the country.
# * population - The country's population.
# * population_growth- The country's population growth as a percentage.
# * birth_rate - The country's birth rate, or the number of births a year per 1,000 people.
# * death_rate - The country's death rate, or the number of death a year per 1,000 people.
# * area- The country's total area (both land and water).
# * area_land - The country's land area in square kilometers.
# * area_water - The country's waterarea in square kilometers.

# %%
q = "SELECT * FROM facts limit 5;"
pd.read_sql_query(q, conn)
# Out:
#    id code         name     area  area_land  area_water  population  \
# 0   1   af  Afghanistan   652230     652230           0    32564342
# 1   2   al      Albania    28748      27398        1350     3029278
# 2   3   ag      Algeria  2381741    2381741           0    39542166
# 3   4   an      Andorra      468        468           0       85580
# 4   5   ao       Angola  1246700    1246700           0    19625353
#
#    population_growth  birth_rate  death_rate  migration_rate
# 0               2.32       38.57       13.89            1.51
# 1               0.30       12.92        6.58            3.30
# 2               1.84       23.67        4.31            0.92
# 3               0.12        8.13        6.96            0.00
# 4               2.78       38.78       11.49            0.46

# %%
q = "SELECT MIN(population),MAX(population),MIN(population_growth),MAX(population_growth) FROM facts;"
pd.read_sql_query(q, conn)
# Out:
#    MIN(population)  MAX(population)  MIN(population_growth)  \
# 0                0       7256490011                     0.0
#
#    MAX(population_growth)
# 0                    4.02

# %%
q = "SELECT name FROM facts where population=0;"
pd.read_sql_query(q, conn)
# Out:
#          name
# 0  Antarctica

# %%
q = "SELECT name FROM facts where population=7256490011;"
pd.read_sql_query(q, conn)
# Out:
#     name
# 0  World

# %% [markdown]
# There is no country with 0 population and no country with population 7256490011

# %%
q = "SELECT * FROM facts ;"
df=pd.read_sql_query(q, conn)

# %%
df.head(10)
# Out:
#    id code                 name       area  area_land  area_water  population  \
# 0   1   af          Afghanistan   652230.0   652230.0         0.0  32564342.0
# 1   2   al              Albania    28748.0    27398.0      1350.0   3029278.0
# 2   3   ag              Algeria  2381741.0  2381741.0         0.0  39542166.0
# 3   4   an              Andorra      468.0      468.0         0.0     85580.0
# 4   5   ao               Angola  1246700.0  1246700.0         0.0  19625353.0
# 5   6   ac  Antigua and Barbuda      442.0      442.0         0.0     92436.0
# 6   7   ar            Argentina  2780400.0  2736690.0     43710.0  43431886.0
# 7   8   am              Armenia    29743.0    28203.0      1540.0   3056382.0
# 8   9   as            Australia  7741220.0  7682300.0     58920.0  22751014.0
# 9  10   au              Austria    83871.0    82445.0      1426.0   8665550.0
#
#    population_growth  birth_rate  death_rate  migration_rate
# 0               2.32       38.57       13.89            1.51
# 1               0.30       12.92        6.58            3.30
# 2               1.84       23.67        4.31            0.92
# 3               0.12        8.13        6.96            0.00
# 4               2.78       38.78       11.49            0.46
# 5               1.24       15.85        5.69            2.21
# 6               0.93       16.64        7.33            0.00
# 7               0.15       13.61        9.34            5.80
# 8               1.07       12.15        7.14            5.65
# 9               0.55        9.41        9.42            5.56

# %%
df.hist(df,column=["population","population_growth","birth_rate","death_rate"])
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-10-3dc818b21305> in <module>()
# ----> 1 df.hist(df,column=["population","population_growth","birth_rate","death_rate"])
#
# TypeError: hist_frame() got multiple values for argument 'column'
